# %% [markdown]
# <a href="https://colab.research.google.com/github/szalontai/CD_esquenta/blob/develop/Aquecimento_2_LLM's.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ![alt text](https://encrypted-tbn0.gstatic.com/images?q=tbn%3AANd9GcTK4gQ9nhwHHaSXMHpeggWg7twwMCgb877smkRmtkmDeDoGF9Z6&usqp=CAU)

# %% [markdown]
# # <font color=blue>Aquecimento n° 2 - LLM - Grandes Modelos de Linguagem

# %% [markdown]
# ![capa.png](data:image/png;base64,...)

# %% [markdown]
# # Sorteio Notebook

# %% [markdown]
# ###Regras

# %% [markdown]
# https://bit.ly/4eLp8VA

# %% [markdown]
# # LLM
# https://artificialanalysis.ai/models
#
# https://artificialanalysis.ai/leaderboards/providers
#
# https://llmmodels.org/

# %% [markdown]
# #FIM

# %%
from IPython.core.display import HTML
HTML('<iframe width="380" height="200" src="https://www.youtube.com/embed/NOKfbZ-_BHw" title="Agents – Introdução à criação e funcionamento de agentes de IA" frameborder="0" allow="accelerometer; autoplay; clipboard-write; encrypted-media; gyroscope; picture-in-picture; web-share" referrerpolicy="strict-origin-when-cross-origin" allowfullscreen></iframe>')
# Out:
# /usr/local/lib/python3.10/dist-packages/IPython/core/display.py:724: UserWarning: Consider using IPython.display.IFrame instead
#   warnings.warn("Consider using IPython.display.IFrame instead")
# <iframe width="380" height="200" src="https://www.youtube.com/embed/NOKfbZ-_BHw" title="Agents – Introdução à criação e funcionamento de agentes de IA" frameborder="0" allow="accelerometer; autoplay; clipboard-write; encrypted-media; gyroscope; picture-in-picture; web-share" referrerpolicy="strict-origin-when-cross-origin" allowfullscreen></iframe>

# %% [markdown]
# ##<font color= Brawn>Fique Ligado! Redes Sociais
# https://linktr.ee/cienciadosdados

# %% [markdown]
# ##<font color = Brawn> Anexos

# %% [markdown]
# Google Gemini

# %% [markdown]
# https://colab.research.google.com/drive/1q_Q7guNAWIJ94GZThC2orZ9PZkTJiYBl?usp=sharing

# %% [markdown]
# Meta LLama 3.2

# %% [markdown]
# https://colab.research.google.com/drive/1gkfZw0pRzYvU3efVS1rlfbr8CU3xItTw?usp=sharing

# %% [markdown]
# Anthropic Claude 3.5

# %% [markdown]
# https://colab.research.google.com/drive/1oDjXz68pqyx5UrCkkZrKKdGpaBAAOzpX?usp=sharing

# %% [markdown]
# Mistral Large

# %% [markdown]
# https://colab.research.google.com/drive/1KfcRtg6OVArsJ4_CvurS1OAfxmtyaTA_?usp=sharing

# %% [markdown]
# HugginFace

# %% [markdown]
# https://huggingface.co/spaces/gabrielchua/open-notebooklm
