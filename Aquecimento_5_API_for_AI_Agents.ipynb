# %% [markdown]
# <a href="https://colab.research.google.com/github/szalontai/CD_esquenta/blob/develop/Aquecimento_5_API_for_AI_Agents.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ![alt text](https://encrypted-tbn0.gstatic.com/images?q=tbn%3AANd9GcTK4gQ9nhwHHaSXMHpeggWg7twwMCgb877smkRmtkmDeDoGF9Z6&usqp=CAU)

# %% [markdown]
# # <font color=green>Aquecimento n° 5 - API

# %% [markdown]
# https://serper.dev/
#
# https://exa.ai/

# %% [markdown]
# ![AI Com (1).png](data:image/png;base64,...)

# %% [markdown]
# # Sorteio Notebook

# %% [markdown]
# ###Regras

# %% [markdown]
# https://bit.ly/4eLp8VA

# %% [markdown]
# **Agente de Pesquisa**
# O que estão publicando de inovação

# %% [markdown]
# https://colab.research.google.com/drive/1fPRqA9bkctKu02romVOqXtvaYi9sMvxV?usp=sharing

# %% [markdown]
# **Agente de Análise de Mercado**
#
# Este caso de uso demonstra como combinar busca neural (Exa) com processamento de linguagem natural (OpenAI) para criar uma ferramenta de análise de empresas que pode ser útil para geração de leads de vendas ou pesquisa de concorrentes.

# %% [markdown]
# https://colab.research.google.com/drive/1KIfA3XIzI_cNmgVzPA0CmB2UiL0vu107?usp=sharing

# %% [markdown]
# #FIM

# %%
from IPython.core.display import HTML
HTML('<iframe width="380" height="200" src="https://www.youtube.com/embed/JDFTJgZ-FJ0" title="LLM (Large Language Models) – Modelos de linguagem de larga escala e suas aplicações." frameborder="0" allow="accelerometer; autoplay; clipboard-write; encrypted-media; gyroscope; picture-in-picture; web-share" referrerpolicy="strict-origin-when-cross-origin" allowfullscreen></iframe>')
# Out:
# /usr/local/lib/python3.10/dist-packages/IPython/core/display.py:724: UserWarning: Consider using IPython.display.IFrame instead
#   warnings.warn("Consider using IPython.display.IFrame instead")
# <iframe width="380" height="200" src="https://www.youtube.com/embed/JDFTJgZ-FJ0" title="LLM (Large Language Models) – Modelos de linguagem de larga escala e suas aplicações." frameborder="0" allow="accelerometer; autoplay; clipboard-write; encrypted-media; gyroscope; picture-in-picture; web-share" referrerpolicy="strict-origin-when-cross-origin" allowfullscreen></iframe>

# %% [markdown]
# ##<font color= Brawn>Fique Ligado! Redes Sociais
# https://linktr.ee/cienciadosdados
